# %%
from track_focus import loadFocus
from datetime import datetime

df = create_focus_df()
fig = plotFocus(df)
fig.show()
# Out:
# <div>                            <div id="2d2df9f1-757f-4d9e-be58-5fc055f9e0a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d2df9f1-757f-4d9e-be58-5fc055f9e0a6")) {                    Plotly.newPlot(                        "2d2df9f1-757f-4d9e-be58-5fc055f9e0a6",                        [{"marker": {"color": "red"}, "name": "Focus", "type": "scatter", "x": ["2021-02-16", "2021-02-17", "2021-02-18", "2021-02-19", "2021-02-20", "2021-02-21", "2021-02-22", "2021-02-23", "2021-02-24", "2021-02-25", "2021-02-26", "2021-02-27", "2021-02-28", "2021-03-01", "2021-03-02", "2021-03-03", "2021-03-04", "2021-03-05", "2021-03-06", "2021-03-07", "2021-03-08", "2021-03-09", "2021-03-10", "2021-03-11", "2021-03-12", "2021-03-13", "2021-03-14", "2021-03-15", "202
# ...

# %%
df
# Out:
#           dates     focus
# 0    2021-02-16  0.035000
# 1    2021-02-16  0.000278
# 2    2021-02-16  0.000278
# 3    2021-02-16  0.000278
# 4    2021-02-16  2.823889
# ..          ...       ...
# 855  2021-06-08  0.000000
# 856  2021-06-08  0.976944
# 857  2021-06-08  0.336667
# 858  2021-06-08  0.019444
# 859  2021-06-08  1.545833
#
# [860 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# AttributeError: 'tuple' object has no attribute 'head'
